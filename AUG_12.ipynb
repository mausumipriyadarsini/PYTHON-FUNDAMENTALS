# %% [markdown]
# # NUMBER SYSTEM

# %%
25
# Out:
# 25

# %%
bin(25) #converted number to binary number sydtem
# Out:
# '0b11001'

# %%
bin(30)
# Out:
# '0b11110'

# %%
int(0b11110) #binary coverted to number
# Out:
# 30

# %%
bin(25)
# Out:
# '0b11001'

# %%
oct(25) # convert number to octal number system
# Out:
# '0o31'

# %%
int(0o31) # octal to number system
# Out:
# 25

# %%
hex(1)
# Out:
# '0x1'

# %%
hex(9)
# Out:
# '0x9'

# %%
hex(10)
# Out:
# '0xa'

# %%
hex(13)
# Out:
# '0xd'

# %%
hex(16)
# Out:
# '0x10'

# %%
int(0x10)
# Out:
# 16

# %%
int(0x9)
# Out:
# 9

# %%
int(0x19)
# Out:
# 25

# %%
hex(25)
# Out:
# '0x19'

# %% [markdown]
# # BITWISE OPERATOR

# %% [markdown]
# COMPLEMENT

# %%
~12
# Out:
# -13

# %%
~35
# Out:
# -36

# %%
~18
# Out:
# -19

# %%
12 & 13      #AND
# Out:
# 12

# %%
12|13      #OR
# Out:
# 13

# %%
12^13      #XOR
# Out:
# 1

# %%
12<< 2      #LEFT SIFT
# Out:
# 48

# %%
12<<1
# Out:
# 24

# %%
12>>1      #RIGHT SIFT
# Out:
# 6

# %%
12>>2
# Out:
# 3

# %% [markdown]
# #SWAPPING CONCEPT

# %%
a=5
b=6

# %%
a=b
b=a
print(a)
print(b)
# Out:
# 6
# 6

# %%
a,b=7
a=b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 print(a)
#       2 print(b)
#
# NameError: name 'a' is not defined
