# %%
si='Welcome'
si
# Out:
# 'Welcome'

# %% [markdown]
# STEP SLICING

# %%
si='Welcome'
si[0:7:2]
# Out:
# 'Wloe'

# %%
si[-5:-1]
si
# Out:
# 'Welcome'

# %% [markdown]
# PYTHON TYPE CASTING

# %%
110.65
# Out:
# 110.65

# %%
int(110.65)
# Out:
# 110

# %%
int(True) #convert bool to int
# Out:
# 1

# %%
int(1+2j) #cant convert
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 int(1+2j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
int('10')
# Out:
# 10

# %%
int('mausumi')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 int('mausumi')
#
# ValueError: invalid literal for int() with base 10: 'mausumi'

# %%
#other data type to float

# %%
float(110)
# Out:
# 110.0

# %%
float(True)
# Out:
# 1.0

# %%
float(False)
# Out:
# 0.0

# %%
float(1+2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 float(1+2j)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
float(10)
# Out:
# 10.0

# %%
float('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 float('ten')
#
# ValueError: could not convert string to float: 'ten'

# %%
bool(2)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(2.3)
# Out:
# True

# %%
bool(1+2j)
# Out:
# True

# %%
bool('10')
# Out:
# True

# %%
bool('ten')
# Out:
# True

# %%
bool()
# Out:
# False

# %%
bool(-2)
# Out:
# True

# %% [markdown]
# other dat type to complex

# %%
complex(2)
# Out:
# (2+0j)

# %%
complex(2,4)
# Out:
# (2+4j)

# %%
complex(1,2,3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 complex(1,2,3)
#
# TypeError: complex() takes at most 2 arguments (3 given)

# %%
complex(2.5)
# Out:
# (2.5+0j)

# %%
complex(True)
# Out:
# (1+0j)

# %%
complex(False)
# Out:
# 0j

# %%
complex('10')
# Out:
# (10+0j)

# %%
complex('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 complex('ten')
#
# ValueError: complex() arg is a malformed string

# %%
complex('20','40')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 complex('20','40')
#
# TypeError: complex() argument 'real' must be a real number, not str

# %% [markdown]
# other data type to string

# %%
str(10)
# Out:
# '10'

# %%
str(10.6)
# Out:
# '10.6'

# %%
str(True)
# Out:
# 'True'

# %%
str(1+3j)
# Out:
# '(1+3j)'
