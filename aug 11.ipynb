# %%
2+3
10-6
10*5
# Out:
# 50

# %%
print(2+3)
print(10-6)
print(10*5)
# Out:
# 5
# 4
# 50

# %%
a=10
b=20

print(a)
print(b)
# Out:
# 10
# 20

# %%
print(a,b)
# Out:
# 10 20

# %%
c=30
print(a)
print(b)
print(c)

print(a,b,c)
# Out:
# 10
# 20
# 30
# 10 20 30

# %%
print(10) 
print(10,20) 
print('python') 
print(10,20,'python')
# Out:
# 10
# 10 20
# python
# 10 20 python

# %%
num1=20
num2=30
add=num1+num2
print(add)
# Out:
# 50

# %%
num1=20
num2=30
num3=50
add=num1+num2+num3
print('The addition of',num1,'and',num2,'and',num3,'is=',add)
# Out:
# The addition of 20 and 30 and 50 is= 100

# %%
name='mausumi'
age=24
city='hyderbad city'

print('My name is',name,'and i am',age,'years old form',city)
# Out:
# My name is mausumi and i am 24 years old form hyderbad city

# %% [markdown]
# print() with format method

# %%
num1=20
num2=30
add=num1+num2
print('The addition of {} and {} is = {}'.format(num1 ,num2 ,add))
# Out:
# The addition of 20 and 30 is = 50

# %%
num1=20
num2=30
add=num1+num2
print(f'The addition of {num1} and {num2} is = {add}')
# Out:
# The addition of 20 and 30 is = 50

# %%
print('hello')
print('good evening')
# Out:
# hello
# good evening

# %%
print('hello',end='')
print('good evening')
# Out:
# hellogood evening

# %%
print('hello', end='###')
print('good evening')
# Out:
# hello###good evening

# %%
print('hello','hai','how are you',sep='--->')
# Out:
# hello--->hai--->how are you
