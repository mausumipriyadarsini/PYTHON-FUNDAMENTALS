# %% [markdown]
# VARIABLE

# %%
#SYNTAX=variable_name=value

# %%
age=24
age
# Out:
# 24

# %%
name="mausumi"

# %%
price=30.6
price
# Out:
# 30.6

# %%
is_active= True
print(is_active)
# Out:
# True

# %%
x=20
print(x)
# Out:
# 20

# %%
a=4
b=7
add=a+b
print(add)
# Out:
# 11

# %%
score=30
print(score)
# Out:
# 30

# %%
score=30
print(score)
score=80
print(score)
# Out:
# 30
# 80

# %%
first_name="Mausumi"
second_name="Priyadarsini"
full_name=first_name+second_name
print(full_name)
# Out:
# MausumiPriyadarsini

# %%
length=14
width=3
area=length*width
print(area)
# Out:
# 42

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
a=7
type(a)
# Out:
# int

# %%
first_name='MAUSUMI'
last_name='PRIYADARSINI'
country='HYD'
city='TELENGANA'
age=23
is_marride=False
skill=['HTML','CSS','JS','react','Python']
