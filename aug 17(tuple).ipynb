# %% [markdown]
# TUOLE

# %%
t=()
t
# Out:
# ()

# %%
type(t)
# Out:
# tuple

# %%
t=(10,True,2.3,1+2j,'welcome')
t
# Out:
# (10, True, 2.3, (1+2j), 'welcome')

# %%
t.append(50)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 t.append(50)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
t[0]
# Out:
# 10

# %%
t[0:4]
# Out:
# (10, True, 2.3, (1+2j))

# %%
t
# Out:
# (10, True, 2.3, (1+2j), 'welcome')

# %%
t[0]
# Out:
# 10

# %%
t[0]=100 #tuple is immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 t[0]=100
#
# TypeError: 'tuple' object does not support item assignment

# %%
t.count(10) #count is allowed
# Out:
# 1

# %%
t.index(1+2j) #index is allowed
# Out:
# 3

# %%
t1=(10,20,30)
t1
# Out:
# (10, 20, 30)

# %%
t1*3
# Out:
# (10, 20, 30, 10, 20, 30, 10, 20, 30)

# %%
sbi=(1234,'cizps9768',2000,'hyd')
sbi
# Out:
# (1234, 'cizps9768', 2000, 'hyd')

# %%
sbi.remove(2000) #tuple is immutable
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 sbi.remove(2000)
#
# AttributeError: 'tuple' object has no attribute 'remove'
