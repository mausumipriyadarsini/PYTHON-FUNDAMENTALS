# %%
sqrt(25) #name error
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 sqrt(25) #name error
#
# NameError: name 'sqrt' is not defined

# %%
import math    #module function
math.sqrt(25)
# Out:
# 5.0

# %%
math.floor(3.5)
# Out:
# 3

# %%
math.ceil(3.5)
# Out:
# 4

# %%
math.floor(4.9)
# Out:
# 4

# %%
math.pow(2,3) #power function
# Out:
# 8.0

# %%
m.floor(3.4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 m.floor(3.4)
#
# NameError: name 'm' is not defined

# %%
import math as m
print(m.floor(3.4))
print(m.ceil(3.4))
# Out:
# 3
# 4

# %%
print(m.floor(3.4))
print(m.ceil(3.4))
# Out:
# 3
# 4

# %%
from math function import,pow,floor,ceil,sqrt

print(floor(3.4))
print(ceil(3.4))
print(sqrt(10))
print(pow(2,3))
# Out:
#   Cell In[10], line 1
#     from math function import,pow,floor,ceil,sqrt
#               ^
# SyntaxError: invalid syntax

# %%
from math import * #print all math inbuild function which user reqir

# %% [markdown]
# INPUT FUNCTION input()

# %%
x=input()
x
# Out:
#  8
# '8'

# %%
x=input()
y=input()

z=x+y
print(z)
# Out:
#  8
#  0
# 80

# %%
x=int(input())
y=int(input())

z=
# Out:
#   Cell In[15], line 4
#     z=
#       ^
# SyntaxError: invalid syntax

# %% [markdown]
# input

# %%
help()
# Out:
# Welcome to Python 3.14's help utility! If this is your first time using
# Python, you should definitely check out the tutorial at
# https://docs.python.org/3.14/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To get a list of available
# modules, keywords, symbols, or topics, enter "modules", "keywords",
# "symbols", or "topics".
#
# You can use the following keyboard shortcuts at the main interpreter prompt.
# F1: enter interactive help, F2: enter history browsing mode, F3: enter paste
# mode (press again to exit).
#
# Each module also comes with a one-line summary of what it does; to list
# the modules whose name or summary contain a given string such as "spam",
# enter "modules spam".
#
# To quit this help utility and return to the interpreter,
# enter "q", "quit" or "exit".
# help>  q
# You are now leaving help and returning to the Python interpreter.
# ...

# %%
x=input()
x
# Out:
#  8
# '8'

# %%
x=input()
y=input()
z=x+y
print(z)
# Out:
#  3
#  4
# 34

# %%
print(type(x))
# Out:
# <class 'str'>

# %%
x=int(input())
y=int(input())
z=x+y
print(z)
# Out:
#  3
#  4
# 7

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
x1=input('Enter the first number')
y1=input('Enter the second number')
z1=x1+y1
print(z1)
# Out:
# Enter the first number 4
# Enter the second number 5
# 45

# %%
x1=input('Enter the first number')
a1=int(x1)
y1=input('Enter the second number')
b1=int(y1)
z1=a1+b1
print(z1)
# Out:
# Enter the first number 5
# Enter the second number 8
# 13

# %%
x2=input('Enter the first number')
y2=input('Enter the second number')
z2=x2+y2
print(z2)
# Out:
# Enter the first number 4
# Enter the second number 5
# 45

# %% [markdown]
# user input charector

# %%
ch=input('enter a char')
print(ch)
# Out:
# enter a char mausumi
# mausumi

# %%
print(ch[0])
# Out:
# m

# %%
print(ch[-1])
# Out:
# i

# %%
print(ch[1])
# Out:
# a

# %%
ch=input('enter a char')[0]
print(ch)
# Out:
# enter a char mausumi
# m

# %%
ch=input('enter a char')[1:3]
print(ch)
# Out:
# enter a char mausumi
# au

# %%
result=eval(input('enter an rxpr'
print(ch)
