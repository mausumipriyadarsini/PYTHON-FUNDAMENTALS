# %%
s1="WELCOME TEAM" #one line single quotes and doubble quotes
s1
# Out:
# 'WELCOME TEAM'

# %%
s2= ''' dhin jjk kkkkj
        j di ho iohll'''# paragraph 3 quotes
s2
# Out:
# ' dhin jjk kkkkj\n        j di ho iohll'

# %% [markdown]
# #sring index

# %%
s1[0]
# Out:
# 'W'

# %%
s1[4]
# Out:
# 'O'

# %%
s1[7]
# Out:
# ' '

# %%
s1[14]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 s1[14]
#
# IndexError: string index out of range

# %%
s1[1][2][3]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 s1[1][2][3]
#
# IndexError: string index out of range

# %% [markdown]
# s1

# %% [markdown]
#  #string slicing

# %%
s1[:]
# Out:
# 'WELCOME TEAM'

# %%
s1[1:4]
# Out:
# 'ELC'

# %%
s1[0:4]
# Out:
# 'WELC'

# %%
s1[2:5]
# Out:
# 'LCO'

# %%
s1[3:10]
# Out:
# 'COME TE'

# %%
s1[3:1000]
# Out:
# 'COME TEAM'

# %%
s1[1000000000000000]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 s1[1000000000000000]
#
# IndexError: string index out of range

# %%
s1[3:]
# Out:
# 'COME TEAM'

# %%
s1[:4]
# Out:
# 'WELC'

# %%
s1[:6]
# Out:
# 'WELCOM'

# %% [markdown]
# print() Function

# %%
5+2
5-1
# Out:
# 4

# %%
a=20
b=20

print(a)
print(b)
# Out:
# 20
# 20

# %%
print(a,b)
# Out:
# 20 20

# %%
c=30

print(a)
print(b)
print(c)
# Out:
# 20
# 20
# 30

# %%
print(a,b,c)  #code optimization...
# Out:
# 20 20 30

# %%
num1=20
num2=30
add=num1+num2
print(add)
# Out:
# 50

# %%
name= 'Python'
age=20
city= 'Hydrabad'
